# %% [markdown]
# <a href="https://colab.research.google.com/github/aguaranguay/se-ales/blob/master/parcial_campos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parcial 1 Campos Electromagnéticos
# ## *Alejandro Guaranguay Solarte - 818037*

# %% [markdown]
# ---
#
#
#
# # **Punto 1:**
# **Un conductor circular tiene un radio de 1.5𝑚, dicho conductor se encuentra en reposo en el plano 𝑥−𝑦, el conductor circular tiene una resistencia de 0.05𝐾Ω. Se tiene una densidad de flujo magnético que pasa por la sección interna del conductor circular, indicado por la siguiente expresión.**
#
# $$ \vec{B}=0.5\sin10^3t(-\hat{z}) $$
#
#
#
# ---

# %% [markdown]
# ---
#
#
# ## 1.1. Graficar el campo vectorial $\vec{𝐵}$(espacial).

# %% [markdown]
# Para graficar el campo vectorial espacialmente se va a tomar el instante $t=1$ para graficarse, es decir:
#
# $$ \vec{B}(1)=0.5\sin10^3(1)(-z) $$
# $$ \vec{B}(1)=0.5\sin10^3(-z) $$

# %%
#Se inicializan las librerias a utilizar

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d') 

#Se arma el plano x,y,z

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),   #Devuelve matrices de coordenadas a vectores de coordenadas.Crea matrices de coordenadas para evaluaciones vectorizadas de campos escalares / vectoriales
                         np.arange(-0.8, 1, 0.2),
                         np.arange(-0.8, 1, 0.8))
#Se dan los valores de cada componente en este caso u,v,w

u = 0 
v = 0
w = -0.5*np.sin(10**3)

#Finalmente se grafica

ax.quiver(x, y, z, u, v, w, length=0.2, color = 'green')

plt.show()

# %% [markdown]
# ---
#
#
# ## 1.2. Calcular la corriente eléctrica en el conductor circular.

# %% [markdown]
# Primero se identifica que se tiene un claro caso de la ley de inducción de faraday ya que tenemos una densidad de flujo magnético que genera un voltaje en una espira.
#
# Entonces para comenzar se necesita hallar ese voltaje que es la FEM inducida en la espira el cual se calcula mediante el flujo magnetico sobre la suberficie de la espira con la siguiente ecuación:
#
# $$ e = -N \iint_S \frac{\partial \vec{B} }{ \partial t} ds$$
#
# Se halla el flujo magnético $\frac{\partial \vec{B} }{ \partial t}$ de la siguiente manera:
#
#
#
# $$ \frac{\partial \vec{B} }{ \partial t} = \frac{\partial }{ \partial t} ( 0.5\sin10^3t(-z)) = 500\cos(10^3t)(-\hat{z}) $$
#
# $$ \frac{\partial \vec{B} }{ \partial t} = 500\cos(10^3t)(-\hat{z}) $$
#
# Ya hallado el flujo magnetico ahora se van a cuantizar las lineas del flujo magnético que estan pasando por la superficie circular del conductor como se muestra a continuación, donde se escoge la dirección del $ds$ en $(-\hat{z})$, la cual es la misma dirección de $\vec{B}$:
#
# $$ e = -N \iint_S \frac{\partial \vec{B} }{ \partial t} ds$$
#
#   $$ e = -N \iint_S 500\cos(10^3t)(-\hat{z}) ds(-\hat{z})$$
#
# Multiplicando los vectores unitarios:
#
# $$(-\hat{z})(-\hat{z})=1$$
#
# Se tiene qué:
#
#   $$ e = -N \iint_S 500\cos(10^3t) ds$$
#
# Se sabe que la integral no depende del tiempo entonces se sacan todos lo que no dependa de ds:
#
#    $$ e = -N \times 500\cos(10^3t)) \iint_S  ds$$
#
# Se sabe que se quiere hallar el flujo en la superficie, por lo tanto la integral da como resultado el área del circulo que depende del radio que el problema nos ilustra
#
#   $$ e = -N \times 500\cos(10^3t) \times A_\circ $$
#   $$ e = -N \times 500\cos(10^3t) \times \pi r^2 $$
#
#    Se tiene que $N=1$ y $r = 1.5m$, entonces:
#
#   $$ e = -1 \times 500\cos(10^3t) \times \pi \times 1.5^2 $$
#    $$ e = -1125 \pi \cos(10^3t)[v] $$
#
# Ahora para hallar la corriente en el conductor se utiliza la ley de ohm:
#
# $$ V=RI $$
#
# $$ I=\frac{V}{R} $$
#
# Entonces con $ V= e = -1125 \pi \cos(10^3t)[v] $ y $R=0.0 5 𝐾[\Omega]$
#
# $$ I=\frac{-1125 \pi \cos(10^3t)[v]}{0. 05 𝐾[\Omega]} $$
#
# $$ I=- \frac{45}{2} \pi \cos(10^3t)[A] $$
#
# $$ I=- 22.5 \pi \cos(10^3t)[A] $$
#
#
# $$ I=- 70.68583471 \cos(10^3t)[A] $$

# %% [markdown]
# ---
#
#
#
# ## 1.3. Graficar la corriente eléctrica en una ventana temporal de 100𝑚𝑠.

# %% [markdown]
# Se va a graficar una ventana de la corriente en el tiempo

# %% [markdown]
# ---
#
#
#
# ## 1.4. Graficar la corriente si el radio del conductor circular cambia a 3.7𝑚.

# %% [markdown]
# Primero Calculamos la FEM con el radio propuesto por el ejercicio
#
# $$ e = -N \times 500\cos(10^3t) \times \pi r^2 $$
#
# $$ e = -500\cos(10^3t) \times \pi \times (3.7)^2 $$
#
# $$ e = -6845\pi\cos(10^3t) $$
#
# Y ahora se calcula la corriente de la misma manera que en el punto 1.2 pero con $V=e=-6845\pi\cos(10^3t)$
#
# $$ I=\frac{V}{R} $$
#
# $$ I=\frac{-6845\pi\cos(10^3t)[v]}{0. 05 𝐾[\Omega]} $$
#
# $$ I=- 136.9 \pi \cos(10^3t)[A] $$
#
# $$ I=- 430.0840343 \cos(10^3t)[A] $$
#
# Ya con la nueva función corriente se va a gráficar de la misma manera que en el punto anterior

# %%
#No volvemos a definir el vector tiempo por que ya está definido, entonces solo definimos la función de corriente

i=-136.9*np.pi*np.cos(10**3*t)

#Finalmente se grafica

plt.plot(t,i, label="$i(t)$")
plt.legend()
plt.xlabel('$t[s]$')
plt.grid()
plt.ylabel('$i(t)$')
plt.title("Corriente en el tiempo")
plt.show()

# %% [markdown]
# Se nota que la forma de la onda de corriente es la misma para ambos casos, pero la amplitud de la corriente aumenta para el nuevo radio, entonces se puede decir, que entre más radio hay, más voltaje, y por lo tanto más corriente.

# %% [markdown]
# ---
#
#
#
# ## 1.5. Calcular nuevamente la corriente eléctrica para el siguiente campo magnético.
#
# $$\vec{𝐵} =3\sqrt{2}\sin 10^3𝑡 (−\hat{x})$$

# %% [markdown]
# Se identifica que la dirección de el campo magnético $\vec{B}$ está en dirección $(−\hat{x})$, como lo que queremos hallar es la FEM induciada en el conductor, si el campo magnético esta atravesando paralelamente la espira, la cuantificación de las lineas del flujo magnético que atraviesan por la superficie del conductor es cero, puesto a que no están atravesando la superficie, porque las lineas de campo son paralelas a la superficie.
#
# Esto se puede mostrar con la ecuación de la fem, en donde escogemos la dirección del $ds$ en $-\hat{z}$ y tenemos que la dirección de $\vec{B}$ es $(−\hat{x})$:
#
#
#
# $$ e = -N \iint_S \frac{\partial \vec{B} }{ \partial t} (−\hat{x}) ds (-\hat{z})$$
#
# Multiplicando los vectores unitarios:
#
# $$(-\hat{x})(-\hat{z})=0$$
#
# Entonces se tiene qué:
#
#   $$ e = 0 $$
#
# Como no hay FEM inducida, es correcto decir que tampoco hay corriente inducida en el conductor.

# %% [markdown]
# ---
#
#
# # **Punto 2:**
#
# **La intensidad de campo eléctrico en el espacio vacío esta dado por la siguiente expresión.**
# $$\vec{E} = E_0\cos\omega(t−\frac{z}{v})\hat{x}$$

# %% [markdown]
# ---
#
#
# ## 2.1. Determinar las componentes de la intensidad de campo magnético $\vec{H}$.

# %% [markdown]
# Se identifica que hay un campo eléctrico en el vacío, entonces podemos hacer uso de la ley de Gauss para campo magnético para determinar el campo magnético de la sigiente forma:
#
# $$ \nabla \times \vec{E} = -\frac{\partial}{\partial t} \vec{B} $$
#
# Hallamos el rotacional del campo eléctrico para luego hallar el campo mganético.
#
#
#
# $$ \nabla \times \vec{E} = det\begin{equation}
# \begin{bmatrix}
# \hat{x} & \hat{y} & \hat{z}\\
# \frac{\partial}{\partial x} & \frac{\partial}{\partial y} & \frac{\partial}{\partial z}\\
# \vec{E_x} & \vec{E_y} & \vec{E_z}
# \end{bmatrix}
#  =  det
# \begin{bmatrix}
# \hat{x} & \hat{y} & \hat{z}\\
# \frac{\partial}{\partial x} & \frac{\partial}{\partial y} & \frac{\partial}{\partial z}\\
# \vec{E_x} & 0 & 0
# \end{bmatrix}
# \end{equation}  $$
#
# Se sabe que el campo eléctrico solo tiene componente en $\hat{x}$ entonces las demas componentes son cero
#
# $$ \nabla \times \vec{E} = det\begin{bmatrix}
# \hat{x} & \hat{y} & \hat{z}\\
# \frac{\partial}{\partial x} & \frac{\partial}{\partial y} & \frac{\partial}{\partial z}\\
# \vec{E_x} & 0 & 0
# \end{bmatrix} =(0-0)\hat{x}-(0-\frac{\partial}{\partial z}\vec{E_x})\hat{y}+(0-\frac{\partial}{\partial y}\vec{E_x})\hat{z} $$
#
# Como $E_x$ no depende de y, entonces la $\frac{\partial}{\partial y}\vec{E_x}=0$
#
# $$ \nabla \times \vec{E} = 0\hat{x}-(-\frac{\partial}{\partial z}\vec{E_x})\hat{y}+0\hat{z} =(\frac{\partial}{\partial z}\vec{E_x})\hat{y} $$
#
# Entonces hay que derivar el campo eléctrico en $\hat{x}$ con respecto de $z$.
#
# $$ \nabla \times \vec{E} = (\frac{\partial}{\partial z}\vec{E_x})\hat{y} = \Big[\frac{\partial}{\partial z}\Big( E_0\cos\big(\omega(t−\frac{z}{v})\big)\Big)\Big]\hat{y} $$
#
# Entonces se tiene que el rotor de $\vec{E}$ es:
#
#
#
# $$ \nabla \times \vec{E} =  \frac{E_0\omega}{v}\sin \left(\omega\left(t-\frac{z}{v}\right)\right)\hat{y}$$
#
# Por lo tanto:
#
# $$\nabla \times \vec{E} =  -\frac{\partial}{\partial t} \vec{B} =  \frac{E_0\omega}{v}\sin \left(\omega\left(t-\frac{z}{v}\right)\right)\hat{y}$$
#
# Entonces se puede hallar el campo magnético $\vec{B}$ integrando el rotacional con respecto a $dt$ de la siguiente manera:
#
# $$-\frac{\partial}{\partial t} \vec{B} =  \nabla \times \vec{E}$$
#
# $$-\int \frac{\partial}{\partial t} \vec{B} dt = \int (\nabla \times \vec{E} )dt$$
#
# $$\vec{B}  = - \int (\nabla \times \vec{E}) dt$$
#
# Entonces integrando se tiene qué:
#
# $$\vec{B}  = - \int \Big[\frac{E_0\omega}{v}\sin \left(\omega\left(t-\frac{z}{v}\right)\right)\hat{y}\Big] dt$$
#
# Entonces el campo magnético $\vec{B}$ es:
#
# $$\vec{B}  =  \frac{E_0}{v}\cos \left(\omega\left(t-\frac{z}{v}\right)\right)\hat{y}$$
#
#
# Ya con el campo magnético hallado solo resta utilizar la ecuación constitutiva $\vec{B}=\mu \vec{H}$ para hallar $\vec{H}$ como se muestra a continuación:
#
# $$\vec{H}=\frac{\vec{B}}{\mu} $$
#
# Como los campos están een el vacío entonces:
#
# $$\vec{H}=\frac{\vec{B}}{\mu_0} $$
#
# La intensidad de campo magnético es:
#
# $$\vec{H}=\frac{E_0}{\mu_0v}\cos \left(\omega\left(t-\frac{z}{v}\right)\right)\hat{y} $$

# %% [markdown]
# ---
#
#
# ## 2.2. Determinar la siguiente relación $\frac{\vec{E\hat{x}}} {\vec{H\hat{y}} }$, tomando; $𝑣= \frac{1}{\sqrt{\mu_0\varepsilon_0}}$

# %% [markdown]
# Se procede a dividir la componente $\hat{x}$ de $\vec{E}$ sobre la componente $\hat{y}$ de $\vec{H}$ como se muestra a continuación:
#
# $$ \frac{\vec{E\hat{x}}} {\vec{H\hat{y}} } = \frac{E_0\cos\big(\omega(t−\frac{z}{v})\big)}{\frac{E_0}{\mu_0 v}\cos \big(\omega(t-\frac{z}{v})\big)} $$
#
# $$ \frac{\vec{E\hat{x}}} {\vec{H\hat{y}} } = \frac{\frac{E_0}{1}}{\frac{E_0}{\mu_0 \frac{1}{\sqrt{\mu_0\varepsilon_0}}}} = \frac{\mu_0}{\sqrt{\mu_0\varepsilon_0}}$$
#
# $$ \frac{\vec{E\hat{x}}} {\vec{H\hat{y}} } =\sqrt{\frac{\mu_0}{\varepsilon_0}}$$

# %% [markdown]
# ---
#
#
# ## 2.3. Graficar el campo eléctrico y la intensidad de campo magnético (campos vectoriales espaciales).

# %% [markdown]
# Se van a gracicar los campos vectoriales de la misma manera que en el punto 1.1, y se van a tomar los valores de $E_0=0.5$; $f=180kHz$; $𝑣= \frac{1}{\sqrt{\mu_0\varepsilon_0}}$; $z=0.1$; $\mu_0=4\pi10^{−7}$; $\varepsilon_0= \frac{1}{36\pi 10^{−9}}$ que aparecen en el punto 2.4 y el instante $t=0$ para graficar los dos campos, es decir:
#
# Para el campo eléctrico:
#
# $$ \vec{E}(0) = E_0\cos\big(\omega((0)−\frac{z}{v})\big) $$
# $$ \vec{E}(0) = E_0\cos\big(−\omega\frac{z}{v}\big) $$
#
# Para la intensidad de campo magnético:
#
# $$ \vec{H}(0)=\frac{E_0}{\mu_0v}\cos\big(\omega((0)-\frac{z}{v})\big) $$
# $$ \vec{H}(0)=\frac{E_0}{\mu_0v}\cos\big(-\omega\frac{z}{v}\big) $$

# %% [markdown]
# ###Gráfica de $\vec{E}$ (espacial)

# %%
#Se inicializan las librerias a utilizar

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d') 

#Se arma el plano x,y,z

i, j, k = np.meshgrid(np.arange(-1, 1, 0.2),   #Devuelve matrices de coordenadas a vectores de coordenadas.Crea matrices de coordenadas para evaluaciones vectorizadas de campos escalares / vectoriales
                         np.arange(-1, 1, 0.2),
                         np.arange(-1, 1, 0.9))

#damos los valores de E0, f, v, z_0, mu_0, ep_0 

E=0.5
f=180*10**3
w=2*np.pi*f
mu_0=4*np.pi*10**(-7)
ep_0=1/(36*np.pi*10**(-9))
z_0=0.1
v=1/np.sqrt(mu_0*ep_0)


#Se dan los valores de cada componente en este caso para el campo eléctrico

x = E*np.cos(-w*(z_0/v)) 
y = 0
z = 0

#Finalmente se grafica

ax.quiver(i, j, k, x, y, z, length=0.2, color = 'green')

plt.show()

# %% [markdown]
# ###Gráfica de $\vec{H}$ (espacial)

# %%
#Se inicializan las librerias a utilizar

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d') 

#Se arma el plano x,y,z

i, j, k = np.meshgrid(np.arange(-1, 1, 0.2),   #Devuelve matrices de coordenadas a vectores de coordenadas.Crea matrices de coordenadas para evaluaciones vectorizadas de campos escalares / vectoriales
                         np.arange(-1, 1, 0.2),
                         np.arange(-1, 1, 0.9))

#damos los valores de E0, f, v, z_0, mu_0, ep_0 

E=0.5
f=180*10**3
w=2*np.pi*f
mu_0=4*np.pi*10**(-7)
ep_0=1/(36*np.pi*10**(-9))
z_0=0.1
v=1/np.sqrt(mu_0*ep_0)


#Se dan los valores de cada componente en este caso para la intensidad de campo magnético

x = 0
y = (E/(mu_0*v))*np.cos(-w*(z_0/v))
z = 0

#Finalmente se grafica

ax.quiver(i, j, k, x, y, z, length=0.0000001, color = 'green')

plt.show()

# %% [markdown]
# ---
#
#
# ## 2.4. Graficar la intensidad de campo magnético $\vec{H}$ , sí:  $E_0=0.5$; $f=180kHz$; $𝑣= \frac{1}{\sqrt{\mu_0\varepsilon_0}}$; $z=0.1$; $\mu_0=4\pi10^{−7}$; $\varepsilon_0= \frac{1}{36\pi 10^{−9}}$ en una ventana temporal de $100𝑚𝑠$.

# %% [markdown]
# Se va a graficar exactamente igual que en el punto 1.3

# %%
import matplotlib.pyplot as plt
import numpy as np

#Primero definimos el vector de tiempo que va a generar la ventana de 0s a 100ms

t=np.linspace(0,100*10**(-3),1000)

#damos los valores de E0, f, v, z_0, mu_0, ep_0 

E=0.5
f=180*10**3
w=2*np.pi*f
mu_0=4*np.pi*10**(-7)
ep_0=1/(36*np.pi*10**(-9))
z_0=0.1
v=1/np.sqrt(mu_0*ep_0)

#ahora definimos la función de intensidad de campo

H=(E/(mu_0*v))*np.cos(w*(t-z_0/v))

#Finalmente se grafica

plt.plot(t,H, label="$H$")
plt.legend()
plt.xlabel('$t[s]$')
plt.grid()
plt.ylabel('$H$')
plt.title("Intensidad de Campo Magnético en el tiempo")
plt.show()

# %% [markdown]
# ---
#
#
# ## 2.5. ¿La relación $\frac{\vec{E}\hat{x}}{\vec{H}\hat{y}}$, es un campo escalar o un campo vectorial?

# %% [markdown]
# Puesto a que la relación es una división que dá como resultado la constante:
#
# $$ \frac{\vec{E\hat{x}}} {\vec{H\hat{y}} } =\sqrt{\frac{\mu_0}{\varepsilon_0}}$$
#
# Entonces dicha relación es un campo escalar.
